# %%
import pandas as pd
import re
import nltk

# %%
raw_data = pd.read_csv('./data/raw_data.csv')

raw_data
# Out:
#                                                  German  \
# 0     @MeehrChaos @neSeemannsbraut Naja, ich war ger...
# 1     @FrauZimt „Ich finde, in der Stadt hält man da...
# 2     „Ach, diese Hitzewellen, dieser Klimawandel, s...
# 3            @regenmuseum Harte, äh, trockene Zeiten… 😢
# 4                                        @rainerklute 💡
# ...                                                 ...
# 1995             #Vertipper des Tages: Sorgiment. \n\n😳
# 1996                  Thread! 👇 https://t.co/YsLyXezyTq
# 1997  RT @SlenderSherbet: When assembling your dog, ...
# 1998  RT @Sophia165540956: Das ist Olga,12Jahre alt....
# 1999                                                NaN
#
#                                                  French  \
# 0     Un début d’accalmie sur le front des incendies...
# 1     Etats-Unis : le plan climat et santé de Joe Bi...
# 2     Marchés d’Europe, Stevenson, luttes féministes...
# 3     Comment Ginko Financial, la plus célèbre banqu...
# 4     L’actrice américaine Anne Heche déclarée morte...
# ...                                                 ...
# 1995  RT @Sante_Gouv: #Canicule | Comment se rafraîc...
# 1996  RT @Sante_Gouv: #Monkeypox | Quels sont les sy...
# 1997  RT @francediplo: #OTAN | Le Parlement 🇫🇷 a rat...
# 1998  RT @Sante_Gouv: #Vaccination | 2ème dose de ra...
# 1999  RT @Elisabeth_Borne: Large majorité au Parleme...
#
#                                                 Italian  \
# 0     Siamo al mondo per vivere una storia d’amore c...
# 1     Chi si crede ricco, vincente e sicuro, fonda t...
# 2     La vecchiaia è la fase della vita più adatta a...
# 3     Quanto è prezioso quel senso di familiarità e ...
# 4     La rinascita di un dialogo passa non dalle par...
# ...                                                 ...
# 1995  "La prima cosa che mi ha colpito è stata l'ema...
# 1996  "Un immediato colpo di fulmine, un prodigio, i...
# 1997  "Un romanzo con una voce, che esprime subito u...
# 1998                                                NaN
# 1999                                                NaN
#
#                                                 Spanish  \
# 0     Cuando el escritor estaba en el escenario, el ...
# 1     El caso de Lee reafirma la concepción popular ...
# 2     La orden de registro al hogar del expresidente...
# 3     La novela "Los versos satánicos", de Salman Ru...
# 4     En Corea del Sur, los conglomerados gigantes d...
# ...                                                 ...
# 1995  El Sol esconde enormes asteroides que no vemos...
# 1996  Lombrices y camarones fueron los primeros en r...
# 1997  Descubren uno de mayores diamantes rosas de to...
# 1998  Los mejores secadores de pelo para llevarte en...
# 1999  Este cometa es el causante de las Perseidas ht...
#
#                                                 English
# 0     We’re told not to dwell on the past, but is no...
# 1     Despite our intuition, Wilson says we're not a...
# 2     The results? The women who saw the profile wer...
# 3     How well do you know yourself?\n\nIn a speed d...
# 4     "I feel like she's a guardian angel of my subc...
# ...                                                 ...
# 1995  RT @patriotact: Brand new episode of Patriot A...
# 1996  RT @patriotact: Hasan has a pitch for how to r...
# 1997  America needs a commissioner: Adam Silver. htt...
# 1998                                                NaN
# 1999                                                NaN
#
# [2000 rows x 5 columns]

# %%
# Check out any null values
raw_data.isna().sum()
# Out:
# German     1
# French     0
# Italian    2
# Spanish    0
# English    2
# dtype: int64

# %% [markdown]
# ## Some Ideas:
# - Lowercase everything
#
# ### Remove
# - `@` + word + ` `
# - Numbers
# - Hashtags
# - Links
# - Special characters such as *:, (, ), etc.*
# - Emojis
# - `"RT"`

# %% [markdown]
# ### Special characters
# - \ - " "( )  / : _ * $ +

# %%
languages = raw_data.columns
languages
# Out:
# Index(['German', 'French', 'Italian', 'Spanish', 'English'], dtype='object')

# %%
def clean_data(text):
    # Hashtag filter
    no_hashtag = text.apply(lambda x: re.sub('#[\w]+','', x)) 

    # Mention filter
    no_mention = no_hashtag.apply(lambda x: re.sub("@([A-Za-z0-9_ßäöüÄÖÜÇâêîôûéàèùëïç]+)|([^0-9A-Za-z_ßäöüÄÖÜâêîôûéàèùëïç \t])|(\w+:\/\/\S+)",' ', x))

    # Remove RT
    no_rt = no_mention.apply(lambda x: re.sub('RT','', x))

    # Remove numbers
    no_num = no_rt.apply(lambda x: re.sub('[0-9]+','', x))

    # Remove extra underscores
    no_underscore = no_num.apply(lambda x: re.sub('_','', x))

    # Lowercase the words
    lowercase = no_underscore.apply(lambda x: x.lower())

    # Remove traces of ampersand
    no_ampersand = lowercase.apply(lambda x: re.sub(' amp ','', x))

    # Remove leading and trailing whitespaces
    no_space = no_ampersand.apply(lambda x: x.strip())

    # Remove extra spaces in between words
    cleaned = no_space.apply(lambda x: " ".join(x.split()))

    return cleaned

# %% [markdown]
# # TODO
# ### Condense all the lambda functions into a single one and pass a series as the argument

# %%
no_punctuation = pd.DataFrame()

for language in languages:
    sentences = raw_data[language].dropna(axis=0)
    no_punctuation[language] = clean_data(sentences)

# %%
def read_stopwords(language):
    nltk.download("stopwords")
    return nltk.corpus.stopwords.words(language.lower())

def remove_stopwords(text, stopwords):
    text = text.split()
    stopwords_removed = [word for word in text if word not in stopwords]
    return stopwords_removed

# %%
cleaned_data = pd.DataFrame()

for language in languages:
    # Stopwords
    stopwords = read_stopwords(language)
    
    # Language sentences
    section = no_punctuation[language]
    section_dropped = section.dropna().copy()

    # Filter out stopwords
    no_stopwords = section_dropped.apply(lambda x: remove_stopwords(x, stopwords))

    # "Un-tokenize" the text
    cleaned_text = no_stopwords.apply(lambda x: " ".join([word for word in x]))

    # Save the data as a new column
    cleaned_data[language] = pd.concat([cleaned_data, cleaned_text], axis=1)[language]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Johng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Johng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Johng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Johng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Johng\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
cleaned_data.head()
# Out:
#                                               German  \
# 0  naja gerade frankreich tatsächlich schrecklich...
# 1  finde stadt hält gar fahre abends immer kurz w...
# 2  ach hitzewellen klimawandel schlimm gleich mal...
# 3                           harte äh trockene zeiten
# 4
#
#                                               French  \
# 0              début accalmie front incendies france
# 1  etats unis plan climat santé joe biden adopté ...
# 2  marchés europe stevenson luttes féministes rep...
# 3  comment ginko financial plus célèbre banque se...
# 4  actrice américaine anne heche déclarée morte s...
#
#                                              Italian  \
# 0  mondo vivere storia d amore dio abbracciare au...
# 1  crede ricco vincente sicuro fonda sé chiude di...
# 2  vecchiaia fase vita adatta diffondere lieta no...
# 3  prezioso quel senso familiarità comunità tanto...
# 4  rinascita dialogo passa parole silenzio impunt...
#
#                                              Spanish  \
# 0  escritor escenario agresor subi tarima asest r...
# 1  caso lee reafirma concepci n popular l deres e...
# 2  orden registro hogar expresidente expone trump...
# 3  novela versos sat nicos salman rushdie conside...
# 4  corea sur conglomerados gigantes dominan econo...
#
#                                              English
# 0  told dwell past nostalgia exception weekly new...
# 1  despite intuition wilson says actually good pr...
# 2  results women saw profile poor predicting eith...
# 3  well know speed dating study women rated much ...
# 4  feel like guardian angel subconscious remind c...

# %% [markdown]
# Save the resulting data to a csv file

# %%
cleaned_data.to_csv('./data/cleaned_data.csv', index=False)
